# %% [markdown]
# ## Lab 01 Automated Project: Planning, Estimation, and Allocation

# %%
import yaml
from crewai import Agent, Crew, Task

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Define file paths for YAML configurations
files = {
    "agents": "./config/agents.yaml",
    "tasks": "./config/tasks.yaml",
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, "r") as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs["agents"]
tasks_config = configs["tasks"]

# %%
from typing import List

from pydantic import BaseModel, Field

# %%
class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(
        ..., description="Estimated time to complete the task in hours"
    )
    required_resources: List[str] = Field(
        ..., description="List of resources required to complete the task"
    )


class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(
        ..., description="List of task IDs associated with this milestone"
    )


class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(
        ..., description="List of tasks with their estimates"
    )
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %%
from crewai import LLM

# %%
llm = LLM(model="openai/qwen3-4b", timeout=60, temperature=0.7, stream=False)

# %%
# Creating Agents
project_planning_agent = Agent(llm=llm, **agents_config["project_planning_agent"])

estimation_agent = Agent(llm=llm, **agents_config["estimation_agent"])

resource_allocation_agent = Agent(llm=llm, **agents_config["resource_allocation_agent"])

# %%
# Creating Tasks
task_breakdown = Task(agent=project_planning_agent, **tasks_config["task_breakdown"])

time_resource_estimation = Task(
    agent=estimation_agent, **tasks_config["time_resource_estimation"]
)

resource_allocation = Task(
    agent=resource_allocation_agent,
    output_pydantic=ProjectPlan,  # This is the structured output we want
    **tasks_config["resource_allocation"],
)

# %%
# Creating Crew
crew = Crew(
    agents=[project_planning_agent, estimation_agent, resource_allocation_agent],
    tasks=[task_breakdown, time_resource_estimation, resource_allocation],
    verbose=True,
)

# %%
crew
# Out:
# Crew(id=5235209e-fe2a-47e7-9052-e37a5d8febb1, process=Process.sequential, number_of_agents=3, number_of_tasks=3)

# %%
from IPython.display import Markdown, display

# %%
project = "Website"

industry = "Technology"

project_objectives = "Create a website for a small business"

team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""

project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""

# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %%
# The given Python dictionary
inputs = {
    "project_type": project,
    "project_objectives": project_objectives,
    "industry": industry,
    "team_members": team_members,
    "project_requirements": project_requirements,
}

# Run the crew
result = crew.kickoff(inputs=inputs)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 5235209e-fe2a-47e7-9052-e37a5d8febb1                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Task: Carefully analyze the project_requirements for the Website project and break them down into individual   │
# │  tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are      │
# │  accounted for:                                                                                                 │
# │                                                                                                                 │
# │  - Create a responsive design that works well on desktop and mobile devices                                     │
# │  - Implement a modern, visually appealing user interface with a clean look                                      │
# │  - Develop a user-friendly navigation system with intuitive menu structure                                      │
# │  - Include an "About Us" page highlighting the company's history and values                                     │
# │  - Design a "Services" page showcasing the business's offerings with descriptions                               │
# │  - Create a "Contact Us" page with a form and integrated map for communication                                  │
# │  - Implement a blog section for sharing industry news and company updates                                       │
# │  - Ensure fast loading times and optimize for search engines (SEO)                                              │
# │  - Integrate social media links and sharing capabilities                                                        │
# │  - Include a testimonials section to showcase customer feedback and build trust                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Project Plan for Website Development (Small Business)**                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **1. Project Initiation & Planning (Week 1)**                                                              │
# │  - **Task**: Define project scope, gather requirements, and create timeline.                                    │
# │  - **Scope**: Finalize business goals, target audience, budget, and deliverables.                               │
# │  - **Deliverable**: Project plan document, stakeholder sign-off.                                                │
# │  - **Timeline**: 1 week (Days 1–7).                                                                             │
# │  - **Dependencies**: None.                                                                                      │
# │  - **Team**: John Doe (Project Manager).                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **2. UI/UX Design (Weeks 2–3)**                                                                            │
# │  - **Task**: Create responsive wireframes and mockups for all pages.                                            │
# │  - **Scope**:                                                                                                   │
# │    - Responsive layout (desktop/mobile).                                                                        │
# │    - Clean, modern design with consistent color scheme and typography.                                          │
# │    - Navigation structure (header menu, footer links).                                                          │
# │  - **Deliverable**: Final design files (Figma/Adobe XD), user flow diagram.                                     │
# │  - **Timeline**: Weeks 2–3 (Days 8–21).                                                                         │
# │  - **Dependencies**: Project initiation.                                                                        │
# │  - **Team**: Bob Smith (Designer).                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **3. Navigation System Development (Weeks 4–5)**                                                           │
# │  - **Task**: Implement intuitive menu structure and responsive navigation.                                      │
# │  - **Scope**:                                                                                                   │
# │    - Dropdown menus, mobile hamburger menu.                                                                     │
# │    - Accessibility compliance (keyboard navigation, ARIA labels).                                               │
# │  - **Deliverable**: Functional navigation code (HTML/CSS/JavaScript).                                           │
# │  - **Timeline**: Weeks 4–5 (Days 22–35).                                                                        │
# │  - **Dependencies**: UI/UX design.                                                                              │
# │  - **Team**: Jane Doe (Software Engineer).                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **4. Page Development (Weeks 6–8)**                                                                        │
# │  #### **a. About Us Page**                                                                                      │
# │  - **Task**: Develop content and layout for company history/values.                                             │
# │  - **Scope**:                                                                                                   │
# │    - Hero section, team photos, mission statement.                                                              │
# │    - Responsive design.                                                                                         │
# │  - **Deliverable**: HTML/CSS code with embedded images.                                                         │
# │  - **Timeline**: Weeks 6–7 (Days 36–50).                                                                        │
# │  - **Dependencies**: UI/UX design.                                                                              │
# │                                                                                                                 │
# │  #### **b. Services Page**                                                                                      │
# │  - **Task**: Showcase offerings with descriptions and icons.                                                    │
# │  - **Scope**:                                                                                                   │
# │    - Grid layout, service cards, call-to-action buttons.                                                        │
# │    - Responsive design.                                                                                         │
# │  - **Deliverable**: HTML/CSS code with embedded images.                                                         │
# │  - **Timeline**: Weeks 6–7 (Days 36–50).                                                                        │
# │  - **Dependencies**: UI/UX design.                                                                              │
# │                                                                                                                 │
# │  #### **c. Contact Us Page**                                                                                    │
# │  - **Task**: Build form and integrated map (Google Maps API).                                                   │
# │  - **Scope**:                                                                                                   │
# │    - Form validation, email integration (Formspree/Netlify), map embed.                                         │
# │    - Responsive layout.                                                                                         │
# │  - **Deliverable**: Functional contact page with embedded map.                                                  │
# │  - **Timeline**: Weeks 6–7 (Days 36–50).                                                                        │
# │  - **Dependencies**: UI/UX design.                                                                              │
# │                                                                                                                 │
# │  #### **d. Blog Section**                                                                                       │
# │  - **Task**: Create blog layout and content management system (CMS).                                            │
# │  - **Scope**:                                                                                                   │
# │    - Post grid, author bio, pagination.                                                                         │
# │    - Integration with CMS (WordPress/Wix).                                                                      │
# │  - **Deliverable**: Functional blog homepage and admin panel.                                                   │
# │  - **Timeline**: Weeks 7–8 (Days 51–63).                                                                        │
# │  - **Dependencies**: UI/UX design.                                                                              │
# │                                                                                                                 │
# │  #### **e. Testimonials Section**                                                                               │
# │  - **Task**: Design and develop customer testimonials section.                                                  │
# │  - **Scope**:                                                                                                   │
# │    - Slider or grid layout, client photos, ratings.                                                             │
# │    - Responsive design.                                                                                         │
# │  - **Deliverable**: HTML/CSS code with embedded images.                                                         │
# │  - **Timeline**: Weeks 7–8 (Days 51–63).                                                                        │
# │  - **Dependencies**: UI/UX design.                                                                              │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **5. SEO Optimization (Weeks 7–8)**                                                                        │
# │  - **Task**: Optimize content and structure for search engines.                                                 │
# │  - **Scope**:                                                                                                   │
# │    - Meta tags, alt text for images, URL structure.                                                             │
# │    - Mobile-first indexing, page speed optimization.                                                            │
# │  - **Deliverable**: SEO audit report, optimized code.                                                           │
# │  - **Timeline**: Weeks 7–8 (Days 51–63).                                                                        │
# │  - **Dependencies**: Page development.                                                                          │
# │  - **Team**: Jane Doe (Software Engineer).                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **6. Social Media Integration (Weeks 7–8)**                                                                │
# │  - **Task**: Add social media links and sharing buttons.                                                        │
# │  - **Scope**:                                                                                                   │
# │    - Icons for Facebook, Instagram, LinkedIn.                                                                   │
# │    - Share buttons with open graph metadata.                                                                    │
# │  - **Deliverable**: Integrated social media code.                                                               │
# │  - **Timeline**: Weeks 7–8 (Days 51–63).                                                                        │
# │  - **Dependencies**: UI/UX design.                                                                              │
# │  - **Team**: Jane Doe (Software Engineer).                                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **7. Testing & QA (Weeks 9–10)**                                                                           │
# │  - **Task**: Conduct user testing, bug fixes, and performance checks.                                           │
# │  - **Scope**:                                                                                                   │
# │    - Cross-browser compatibility (Chrome, Firefox, Safari).                                                     │
# │    - Mobile responsiveness.                                                                                     │
# │    - Performance optimization (Google PageSpeed Insights > 90).                                                 │
# │  - **Deliverable**: Test report with fixes applied.                                                             │
# │  - **Timeline**: Weeks 9–10 (Days 64–77).                                                                       │
# │  - **Dependencies**: Page development and SEO.                                                                  │
# │  - **Team**: Alice Johnson & Tom Brown (QA Engineers).                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **8. Deployment & Launch (Week 11)**                                                                       │
# │  - **Task**: Deploy website to hosting platform and launch.                                                     │
# │  - **Scope**:                                                                                                   │
# │    - SSL certificate, domain setup.                                                                             │
# │    - Final review by stakeholders.                                                                              │
# │  - **Deliverable**: Live website with all features operational.                                                 │
# │  - **Timeline**: Week 11 (Day 78).                                                                              │
# │  - **Dependencies**: Testing & QA.                                                                              │
# │  - **Team**: John Doe (Project Manager).                                                                        │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Gantt Chart Timeline**                                                                                   │
# │  ```                                                                                                            │
# │  [Week 1]         [Week 2]        [Week 3]       [Week 4]      [Week 5]     [Week 6]    [Week 7]      [Week 8]  │
# │  [Week 9]   [Week 10]   [Week 11]                                                                               │
# │  | Project Initiation | UI/UX Design | Navigation Dev | Page Dev (A/B) | Page Dev (C/D/E) | SEO + Social |      │
# │  Testing | Deployment |                                                                                         │
# │  ```                                                                                                            │
# │  **Dependencies**:                                                                                              │
# │  - UI/UX design must precede all development.                                                                   │
# │  - Navigation dev depends on UI/UX.                                                                             │
# │  - Page development depends on UI/UX and navigation.                                                            │
# │  - SEO/social integration happens in parallel with page dev.                                                    │
# │  - Testing occurs after all development and SEO.                                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **Deliverables Summary**:                                                                                      │
# │  1. Project plan document (Week 1).                                                                             │
# │  2. Design mockups (Weeks 2–3).                                                                                 │
# │  3. Navigation code (Weeks 4–5).                                                                                │
# │  4. Page codes (About Us, Services, Contact Us, Blog, Testimonials) (Weeks 6–8).                                │
# │  5. SEO optimization report (Weeks 7–8).                                                                        │
# │  6. Social media integration (Weeks 7–8).                                                                       │
# │  7. QA test report (Weeks 9–10).                                                                                │
# │  8. Live website (Week 11).                                                                                     │
# │                                                                                                                 │
# │  **Key Metrics**:                                                                                               │
# │  - Page speed: >90 on Google PageSpeed Insights.                                                                │
# │  - Mobile responsiveness: 100% across all pages.                                                                │
# │  - SEO ranking: Top 3 for target keywords within 2 weeks of launch.                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 7be31935-95a4-46d5-902e-c5966892ea8d                                                                     │
# │  Agent: The Ultimate Project Planner                                                                            │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort         │
# │  required. Use historical data, task complexity, and available resources to provide a realistic estimation for  │
# │  each task.                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Website Project Estimation Report**                                                                          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **1. Project Initiation & Planning (Week 1)**                                                              │
# │  - **Time**: 7 days (1 week).                                                                                   │
# │  - **Resources**: John Doe (Project Manager).                                                                   │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Define scope, gather requirements, create timeline.                                                 │
# │    - Risk: Stakeholder sign-off delays if requirements are unclear.                                             │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **2. UI/UX Design (Weeks 2–3)**                                                                            │
# │  - **Time**: 14 days (2 weeks).                                                                                 │
# │  - **Resources**: Bob Smith (Designer).                                                                         │
# │  - **Effort**: High.                                                                                            │
# │    - Tasks: Responsive wireframes, mockups, user flow diagrams.                                                 │
# │    - Risk: Design revisions may extend timeline if stakeholder feedback is frequent.                            │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **3. Navigation System Development (Weeks 4–5)**                                                           │
# │  - **Time**: 14 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe (Software Engineer).                                                                 │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Dropdown menus, mobile navigation, accessibility compliance.                                        │
# │    - Risk: Integration with design may require adjustments.                                                     │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **4. Page Development (Weeks 6–8)**                                                                        │
# │  #### **a. About Us Page**                                                                                      │
# │  - **Time**: 10 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe.                                                                                     │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Hero section, team photos, responsive layout.                                                       │
# │                                                                                                                 │
# │  #### **b. Services Page**                                                                                      │
# │  - **Time**: 10 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe.                                                                                     │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Grid layout, service cards, CTA buttons.                                                            │
# │                                                                                                                 │
# │  #### **c. Contact Us Page**                                                                                    │
# │  - **Time**: 10 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe.                                                                                     │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Form validation, Google Maps API integration.                                                       │
# │                                                                                                                 │
# │  #### **d. Blog Section**                                                                                       │
# │  - **Time**: 14 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe.                                                                                     │
# │  - **Effort**: High.                                                                                            │
# │    - Tasks: CMS integration, post grid, pagination.                                                             │
# │                                                                                                                 │
# │  #### **e. Testimonials Section**                                                                               │
# │  - **Time**: 10 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe.                                                                                     │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Slider/grid layout, client photos, ratings.                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **5. SEO Optimization (Weeks 7–8)**                                                                        │
# │  - **Time**: 14 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe.                                                                                     │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Meta tags, alt text, URL structure, page speed optimization.                                        │
# │    - Risk: SEO tools may require additional time for analysis.                                                  │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **6. Social Media Integration (Weeks 7–8)**                                                                │
# │  - **Time**: 14 days (2 weeks).                                                                                 │
# │  - **Resources**: Jane Doe.                                                                                     │
# │  - **Effort**: Medium.                                                                                          │
# │    - Tasks: Social media icons, open graph metadata, sharing buttons.                                           │
# │    - Risk: API integration issues may delay completion.                                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **7. Testing & QA (Weeks 9–10)**                                                                           │
# │  - **Time**: 14 days (2 weeks).                                                                                 │
# │  - **Resources**: Alice Johnson & Tom Brown (QA Engineers).                                                     │
# │  - **Effort**: High.                                                                                            │
# │    - Tasks: Cross-browser testing, mobile responsiveness, performance checks.                                   │
# │    - Risk: Unexpected bugs may require extended debugging.                                                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **8. Deployment & Launch (Week 11)**                                                                       │
# │  - **Time**: 7 days (1 week).                                                                                   │
# │  - **Resources**: John Doe (Project Manager).                                                                   │
# │  - **Effort**: Low.                                                                                             │
# │    - Tasks: Hosting setup, SSL certificate, stakeholder review.                                                 │
# │    - Risk: Domain or hosting issues may cause delays.                                                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Summary of Risks and Uncertainties**                                                                     │
# │  1. **Design Revisions**: Stakeholder feedback on UI/UX mockups could extend the design phase by 2–3 weeks.     │
# │  2. **Testing Delays**: Unanticipated bugs during QA testing might require additional time.                     │
# │  3. **SEO Performance**: Target keywords may not rank top 3 within 2 weeks of launch due to competition.        │
# │  4. **Dependency Risks**: If UI/UX design is delayed, development tasks (Weeks 4–8) could be postponed.         │
# │  5. **Technical Challenges**: Integrating Google Maps API or CMS might require extra troubleshooting.           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ### **Total Estimated Timeline**                                                                               │
# │  - **Start**: Week 1                                                                                            │
# │  - **End**: Week 11                                                                                             │
# │  - **Total Duration**: 11 weeks (77 days).                                                                      │
# │                                                                                                                 │
# │  This report ensures alignment with the Gantt chart and project goals, balancing resource allocation and risk   │
# │  mitigation for a successful website launch.                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: bda330d0-ba5a-48c9-ab18-4d28cb39fa16                                                                     │
# │  Agent: Expert Estimation Analyst                                                                               │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Task: Strategically allocate tasks for the Website project to team members based on their skills,              │
# │  availability, and current workload. Ensure that each task is assigned to the most suitable team member and     │
# │  that the workload is evenly distributed.                                                                       │
# │                                                                                                                 │
# │  Team members:                                                                                                  │
# │                                                                                                                 │
# │  - John Doe (Project Manager)                                                                                   │
# │  - Jane Doe (Software Engineer)                                                                                 │
# │  - Bob Smith (Designer)                                                                                         │
# │  - Alice Johnson (QA Engineer)                                                                                  │
# │  - Tom Brown (QA Engineer)                                                                                      │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "tasks": [                                                                                                   │
# ...
# │        "milestone_name": "Testing & QA",                                                                        │
# │        "tasks": ["Conduct user testing, bug fixes, and performance checks"]                                     │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Deployment & Launch",                                                                 │
# │        "tasks": ["Deploy website to hosting platform and launch"]                                               │
# │      }                                                                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: f29b5695-b20c-4bb0-8b86-41572ad85593                                                                     │
# │  Agent: Resource Allocation Strategist                                                                          │
# │                                                                                                                 │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 5235209e-fe2a-47e7-9052-e37a5d8febb1                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output:                                                                                                  │
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "tasks": [                                                                                                   │
# │      {                                                                                                          │
# │        "task_name": "Define project scope, gather requirements, and create timeline",                           │
# │        "estimated_time_hours": 40.0,                                                                            │
# │        "required_resources": ["John Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create responsive wireframes and mockups for all pages",                                   │
# │        "estimated_time_hours": 60.0,                                                                            │
# │        "required_resources": ["Bob Smith"]                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Implement intuitive menu structure and responsive navigation",                             │
# │        "estimated_time_hours": 35.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Develop content and layout for company history/values",                                    │
# │        "estimated_time_hours": 25.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Showcase offerings with descriptions and icons",                                           │
# │        "estimated_time_hours": 25.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Build form and integrated map (Google Maps API)",                                          │
# │        "estimated_time_hours": 30.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Create blog layout and content management system (CMS)",                                   │
# │        "estimated_time_hours": 45.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Design and develop customer testimonials section",                                         │
# │        "estimated_time_hours": 25.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Optimize content and structure for search engines",                                        │
# │        "estimated_time_hours": 30.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Add social media links and sharing buttons",                                               │
# │        "estimated_time_hours": 25.0,                                                                            │
# │        "required_resources": ["Jane Doe"]                                                                       │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Conduct user testing, bug fixes, and performance checks",                                  │
# │        "estimated_time_hours": 60.0,                                                                            │
# │        "required_resources": ["Alice Johnson", "Tom Brown"]                                                     │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "task_name": "Deploy website to hosting platform and launch",                                            │
# │        "estimated_time_hours": 20.0,                                                                            │
# │        "required_resources": ["John Doe"]                                                                       │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "milestones": [                                                                                              │
# │      {                                                                                                          │
# │        "milestone_name": "Project Initiation & Planning",                                                       │
# │        "tasks": ["Define project scope, gather requirements, and create timeline"]                              │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "UI/UX Design",                                                                        │
# │        "tasks": ["Create responsive wireframes and mockups for all pages"]                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Navigation System Development",                                                       │
# │        "tasks": ["Implement intuitive menu structure and responsive navigation"]                                │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Page Development (About Us, Services, Contact Us)",                                   │
# │        "tasks": ["Develop content and layout for company history/values", "Showcase offerings with              │
# │  descriptions and icons", "Build form and integrated map (Google Maps API)"]                                    │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Page Development (Blog, Testimonials)",                                               │
# │        "tasks": ["Create blog layout and content management system (CMS)", "Design and develop customer         │
# │  testimonials section"]                                                                                         │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "SEO Optimization & Social Media Integration",                                         │
# │        "tasks": ["Optimize content and structure for search engines", "Add social media links and sharing       │
# │  buttons"]                                                                                                      │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Testing & QA",                                                                        │
# │        "tasks": ["Conduct user testing, bug fixes, and performance checks"]                                     │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "milestone_name": "Deployment & Launch",                                                                 │
# │        "tasks": ["Deploy website to hosting platform and launch"]                                               │
# │      }                                                                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
import pandas as pd

# %%
costs = (
    0.150
    * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens)
    / 1_000_000
)
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.model_dump()])

df_usage_metrics
# Out:
# Total costs: $0.0017
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0         11226           5526                     0               5700
#
#    successful_requests
# 0                    3

# %%
result.pydantic.model_dump()
# Out:
# {'tasks': [{'task_name': 'Define project scope, gather requirements, and create timeline',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Create responsive wireframes and mockups for all pages',
#    'estimated_time_hours': 60.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement intuitive menu structure and responsive navigation',
#    'estimated_time_hours': 35.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Develop content and layout for company history/values',
#    'estimated_time_hours': 25.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Showcase offerings with descriptions and icons',
#    'estimated_time_hours': 25.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Build form and integrated map (Google Maps API)',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create blog layout and content management system (CMS)',
#    'estimated_time_hours': 45.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Design and develop customer testimonials section',
#    'estimated_time_hours': 25.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Optimize content and structure for search engines',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Add social media links and sharing buttons',
#    'estimated_time_hours': 25.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Conduct user testing, bug fixes, and performance checks',
#    'estimated_time_hours': 60.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Deploy website to hosting platform and launch',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['John Doe']}],
#  'milestones': [{'milestone_name': 'Project Initiation & Planning',
#    'tasks': ['Define project scope, gather requirements, and create timeline']},
#   {'milestone_name': 'UI/UX Design',
#    'tasks': ['Create responsive wireframes and mockups for all pages']},
#   {'milestone_name': 'Navigation System Development',
#    'tasks': ['Implement intuitive menu structure and responsive navigation']},
#   {'milestone_name': 'Page Development (About Us, Services, Contact Us)',
#    'tasks': ['Develop content and layout for company history/values',
#     'Showcase offerings with descriptions and icons',
#     'Build form and integrated map (Google Maps API)']},
#   {'milestone_name': 'Page Development (Blog, Testimonials)',
#    'tasks': ['Create blog layout and content management system (CMS)',
#     'Design and develop customer testimonials section']},
#   {'milestone_name': 'SEO Optimization & Social Media Integration',
#    'tasks': ['Optimize content and structure for search engines',
#     'Add social media links and sharing buttons']},
#   {'milestone_name': 'Testing & QA',
#    'tasks': ['Conduct user testing, bug fixes, and performance checks']},
#   {'milestone_name': 'Deployment & Launch',
#    'tasks': ['Deploy website to hosting platform and launch']}]}

# %%
tasks = result.pydantic.model_dump()["tasks"]
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption(
    "Task Details"
).set_table_styles([{"selector": "th, td", "props": [("font-size", "120%")]}])
# Out:
# <style type="text/css">
# #T_bfbc7 th {
#   font-size: 120%;
# }
# #T_bfbc7  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_bfbc7" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bfbc7_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_bfbc7_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_bfbc7_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bfbc7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bfbc7_row0_col0" class="data row0 col0" >Define project scope, gather requirements, and create timeline</td>
#       <td id="T_bfbc7_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_bfbc7_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bfbc7_row1_col0" class="data row1 col0" >Create responsive wireframes and mockups for all pages</td>
#       <td id="T_bfbc7_row1_col1" class="data row1 col1" >60.000000</td>
#       <td id="T_bfbc7_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bfbc7_row2_col0" class="data row2 col0" >Implement intuitive menu structure and responsive navigation</td>
#       <td id="T_bfbc7_row2_col1" class="data row2 col1" >35.000000</td>
#       <td id="T_bfbc7_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bfbc7_row3_col0" class="data row3 col0" >Develop content and layout for company history/values</td>
#       <td id="T_bfbc7_row3_col1" class="data row3 col1" >25.000000</td>
#       <td id="T_bfbc7_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bfbc7_row4_col0" class="data row4 col0" >Showcase offerings with descriptions and icons</td>
#       <td id="T_bfbc7_row4_col1" class="data row4 col1" >25.000000</td>
#       <td id="T_bfbc7_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bfbc7_row5_col0" class="data row5 col0" >Build form and integrated map (Google Maps API)</td>
#       <td id="T_bfbc7_row5_col1" class="data row5 col1" >30.000000</td>
#       <td id="T_bfbc7_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bfbc7_row6_col0" class="data row6 col0" >Create blog layout and content management system (CMS)</td>
#       <td id="T_bfbc7_row6_col1" class="data row6 col1" >45.000000</td>
#       <td id="T_bfbc7_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bfbc7_row7_col0" class="data row7 col0" >Design and develop customer testimonials section</td>
#       <td id="T_bfbc7_row7_col1" class="data row7 col1" >25.000000</td>
#       <td id="T_bfbc7_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bfbc7_row8_col0" class="data row8 col0" >Optimize content and structure for search engines</td>
#       <td id="T_bfbc7_row8_col1" class="data row8 col1" >30.000000</td>
#       <td id="T_bfbc7_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bfbc7_row9_col0" class="data row9 col0" >Add social media links and sharing buttons</td>
#       <td id="T_bfbc7_row9_col1" class="data row9 col1" >25.000000</td>
#       <td id="T_bfbc7_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bfbc7_row10_col0" class="data row10 col0" >Conduct user testing, bug fixes, and performance checks</td>
#       <td id="T_bfbc7_row10_col1" class="data row10 col1" >60.000000</td>
#       <td id="T_bfbc7_row10_col2" class="data row10 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_bfbc7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bfbc7_row11_col0" class="data row11 col0" >Deploy website to hosting platform and launch</td>
#       <td id="T_bfbc7_row11_col1" class="data row11 col1" >20.000000</td>
#       <td id="T_bfbc7_row11_col2" class="data row11 col2" >['John Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %%
milestones = result.pydantic.model_dump()["milestones"]
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption(
    "Task Details"
).set_table_styles([{"selector": "th, td", "props": [("font-size", "120%")]}])
# Out:
# <style type="text/css">
# #T_27937 th {
#   font-size: 120%;
# }
# #T_27937  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_27937" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27937_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_27937_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27937_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27937_row0_col0" class="data row0 col0" >Project Initiation & Planning</td>
#       <td id="T_27937_row0_col1" class="data row0 col1" >['Define project scope, gather requirements, and create timeline']</td>
#     </tr>
#     <tr>
#       <th id="T_27937_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27937_row1_col0" class="data row1 col0" >UI/UX Design</td>
#       <td id="T_27937_row1_col1" class="data row1 col1" >['Create responsive wireframes and mockups for all pages']</td>
#     </tr>
#     <tr>
#       <th id="T_27937_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27937_row2_col0" class="data row2 col0" >Navigation System Development</td>
#       <td id="T_27937_row2_col1" class="data row2 col1" >['Implement intuitive menu structure and responsive navigation']</td>
#     </tr>
#     <tr>
#       <th id="T_27937_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27937_row3_col0" class="data row3 col0" >Page Development (About Us, Services, Contact Us)</td>
#       <td id="T_27937_row3_col1" class="data row3 col1" >['Develop content and layout for company history/values', 'Showcase offerings with descriptions and icons', 'Build form and integrated map (Google Maps API)']</td>
#     </tr>
#     <tr>
#       <th id="T_27937_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27937_row4_col0" class="data row4 col0" >Page Development (Blog, Testimonials)</td>
#       <td id="T_27937_row4_col1" class="data row4 col1" >['Create blog layout and content management system (CMS)', 'Design and develop customer testimonials section']</td>
#     </tr>
#     <tr>
#       <th id="T_27937_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27937_row5_col0" class="data row5 col0" >SEO Optimization & Social Media Integration</td>
#       <td id="T_27937_row5_col1" class="data row5 col1" >['Optimize content and structure for search engines', 'Add social media links and sharing buttons']</td>
#     </tr>
#     <tr>
#       <th id="T_27937_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27937_row6_col0" class="data row6 col0" >Testing & QA</td>
#       <td id="T_27937_row6_col1" class="data row6 col1" >['Conduct user testing, bug fixes, and performance checks']</td>
#     </tr>
#     <tr>
#       <th id="T_27937_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27937_row7_col0" class="data row7 col0" >Deployment & Launch</td>
#       <td id="T_27937_row7_col1" class="data row7 col1" >['Deploy website to hosting platform and launch']</td>
#     </tr>
#   </tbody>
# </table>
